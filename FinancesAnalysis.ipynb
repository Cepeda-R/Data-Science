# %% [markdown]
# two lists of data: monthly revenue and monthly expenses for financial year
#
# calculate:
# profit for each month
# profit after tax for each month(tax rate is 30%)
# profit margin for each month = profit after tax / revenue
# good months - where the profit after tax was greater than the
# mean of the year
# bad months - where the profit after tax was less than the mean
# for the year
# best month - where the profit after tax was max for the year
# worst month - where the profit after tax was min for the year
#
# all results need to be presented as lists
# results for dollar values need to be calculated with 0.01precision
# but need to be presented in Units of 1000, with no decimal points
# results for the profit margin ration = % with no decimal
# is okay for tax for any given month to be negative
# negative tax = deferred tax asset

# %%
revenue = [14574.49, 7606.46, 8611.41, 9175.41, 8058.65, 8105.44, 11496.28, 9766.09, 10305.32, 14379.96, 10713.97, 15439.10]
expenses = [12051.82, 5695.07, 12319.20, 12089.72, 8658.57, 840.20, 3285.73, 5821.12, 6976.93, 16618.61, 10054.37, 3803.30]

# %%
#HINT 1 operations with two lists
#iterate through indexis on lists 
profit = list([]) #create a list for results

for i in range(0, len(revenue)): #i for index till the last one
    profit.append(revenue[i] - expenses[i]) #append is putting the operations results into a new object
profit
# Out:
# [2522.67,
#  1911.3900000000003,
#  -3707.790000000001,
#  -2914.3099999999995,
#  -599.9200000000001,
#  7265.24,
#  8210.550000000001,
#  3944.9700000000003,
#  3328.3899999999994,
#  -2238.6500000000015,
#  659.5999999999985,
#  11635.8]

# %%
aftax = [round(i*0.3,2) for i in profit] #for each index on profit it multiplies by the tax
aftax
# Out:
# [756.8,
#  573.42,
#  -1112.34,
#  -874.29,
#  -179.98,
#  2179.57,
#  2463.17,
#  1183.49,
#  998.52,
#  -671.6,
#  197.88,
#  3490.74]

# %%
profit_after_tax = []

for i in range(0, len(aftax)):
    profit_after_tax.append(profit[i]-aftax[i])
profit_after_tax
# Out:
# [1765.8700000000001,
#  1337.9700000000003,
#  -2595.4500000000007,
#  -2040.0199999999995,
#  -419.94000000000005,
#  5085.67,
#  5747.380000000001,
#  2761.4800000000005,
#  2329.8699999999994,
#  -1567.0500000000015,
#  461.71999999999855,
#  8145.0599999999995]

# %%
profitmargin = [] #we can build a list like this anyway

for i in range (0, len(expenses)): #a lista é indeferente 
    profitmargin.append (profit_after_tax[i] / revenue[i]) #between two lists
profitmargin = [round(i*100,2) for i in profitmargin] #quando quero correr um cálculo pela lista arredondado
profitmargin #one list
# Out:
# [12.12,
#  17.59,
#  -30.14,
#  -22.23,
#  -5.21,
#  62.74,
#  49.99,
#  28.28,
#  22.61,
#  -10.9,
#  4.31,
#  52.76]

# %%
import numpy as np

# %%
maftaxl = [np.mean(profit_after_tax)] #turn into a list
maftax = np.mean(profit_after_tax) #yearly mean
maftaxl
# Out:
# [1751.0466666666664]

# %%
good_months = []
for i in range(0, len(profit)):
    good_months.append (profit_after_tax[i] > maftax) #comparing to integir
good_months
# Out:
# [True, False, False, False, False, True, True, True, True, False, False, True]

# %%
bad_months = []
for i in range(0, len(profit)):
    bad_months.append (profit_after_tax[i] < maftax) #comparing to integir
bad_months
# Out:
# [False, True, True, True, True, False, False, False, False, True, True, False]

# %%
best_month =[]
for i in range(0, len(profit)):
    best_month.append(profit_after_tax[i] == max(profit_after_tax))
best_month
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True]

# %%
worst_month =[]
for i in range(0, len(profit)):
    worst_month.append(profit_after_tax[i] == min(profit_after_tax))
worst_month
# Out:
# [False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False]

# %%
#convert all calculation to units of one thousand dollars
revenue_1000 = [round(i/1000,2) for i in revenue] #manter as duas décimas
expenses_1000 = [round(i/1000,2) for i in expenses]
profit_1000 = [round(i/1000,2) for i in profit]
profit_after_tax_1000 = [round(i/1000,2) for i in profit_after_tax]

revenue_1000 = [int(i) for i in revenue_1000] #tornar inteiro
expenses_1000 = [int(i) for i in expenses_1000]
profit_1000 = [int(i) for i in profit_1000]
profit_after_tax_1000 = [int(i) for i in profit_after_tax_1000]

# %%
print ('Revenue : ')
print (revenue_1000)
print ('Expenses : ')
print (expenses_1000)
print ('Profit : ')
print (profit_1000)
print ('Profit After Tax : ')
print (profit_after_tax_1000)
# Out:
# Revenue :
# [14, 7, 8, 9, 8, 8, 11, 9, 10, 14, 10, 15]
# Expenses :
# [12, 5, 12, 12, 8, 0, 3, 5, 6, 16, 10, 3]
# Profit :
# [2, 1, -3, -2, 0, 7, 8, 3, 3, -2, 0, 11]
# Profit After Tax :
# [1, 1, -2, -2, 0, 5, 5, 2, 2, -1, 0, 8]
